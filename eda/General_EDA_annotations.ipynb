# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Cotizaciones Desembolso

# %%
# Reading
df_cotizaciones_desembolso = pd.read_csv("../data/attrition-persona-juridica-bbva/DATA_COTIZACIONES_DESEMBOLSO.txt")

# %%
df_cotizaciones_desembolso
# Out:
#       PERIODO  ID_CLIENTE      ESTADO ESTADO_DESEMBOLSO_COTIZA DIVISA  \
# 0      201707        7478   TARIFARIO             DESEMBOLSADA    USD
# 1      201803       27693     PERDIDA                      NaN    PEN
# 2      201704       54392   TARIFARIO                PENDIENTE    USD
# 3      201709       52553   TARIFARIO                PENDIENTE    PEN
# 4      201808       89268   TARIFARIO                PENDIENTE    PEN
# 5      201712       45580    DEVUELTA                      NaN    PEN
# 6      201702       93115    APROBADA                PENDIENTE    USD
# 7      201701        1587   TARIFARIO             DESEMBOLSADA    USD
# 8      201709       70599    APROBADA             DESEMBOLSADA    USD
# 9      201809       95064    DEVUELTA                      NaN    PEN
# 10     201702       54948   TARIFARIO             DESEMBOLSADA    PEN
# 11     201807       91382    DEVUELTA                      NaN    USD
# ...
